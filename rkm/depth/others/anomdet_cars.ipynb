# %% [markdown]
# Tutorial on "Anomaly detection". Part Python.
#
# Author: Pavlo Mozharovskyi.
#
# This is a Python Notebook for the tutorial
# on "Anomaly detection" given on Wednesday the 6th of April 2022.

# %% [markdown]
# ## 0) Import packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neighbors import LocalOutlierFactor
from sklearn import svm
from sklearn.ensemble import IsolationForest
from depth_routines import depthPrj, depthTuk, depth_tukey

# %% [markdown]
# # Cars + Anomalies

# %% [markdown]
# The data set contains data about speed and breaking distance of 50 old (normal) and 10 new (anomalies) cars.

# %% [markdown]
# ## 1) Import dataset, show elemantary statistics, plot the data

# %%
dfCars = pd.read_csv('carsanom.csv')
print('Data dimension:', dfCars.shape)
dfCars.head()
# Out:
# Data dimension: (60, 2)
#    speed  dist
# 0      4     2
# 1      4    10
# 2      7     4
# 3      7    22
# 4      8    16

# %%
print(np.full(50, "blue"))

X = np.array(dfCars)
plt.scatter(X[:,0], X[:,1], 
            c = np.concatenate((np.full(50, "blue"), np.full(10, "red"))))
plt.xlabel('Speed')
plt.ylabel('Dist')
# Out:
# ['blue' 'blue' 'blue' 'blue' 'blue' 'blue' 'blue' 'blue' 'blue' 'blue'
#  'blue' 'blue' 'blue' 'blue' 'blue' 'blue' 'blue' 'blue' 'blue' 'blue'
#  'blue' 'blue' 'blue' 'blue' 'blue' 'blue' 'blue' 'blue' 'blue' 'blue'
#  'blue' 'blue' 'blue' 'blue' 'blue' 'blue' 'blue' 'blue' 'blue' 'blue'
#  'blue' 'blue' 'blue' 'blue' 'blue' 'blue' 'blue' 'blue' 'blue' 'blue']
# Text(0, 0.5, 'Dist')

# %% [markdown]
# ## 2) Local outlier factor

# %%
outliers_fraction = 0.05
# Create and fit the instance of the class
alg_lof = LocalOutlierFactor(n_neighbors = 5, 
                             contamination = outliers_fraction, 
                             novelty = True)
alg_lof.fit(X[:50,:])
# Generate grid
freq = 100
xs, ys = np.meshgrid(np.linspace(0, 75, freq), np.linspace(-5, 250, freq))
print(xs, ys)
# Calculate the anomaly scores for a map
score0_lof = -alg_lof.decision_function(np.c_[xs.ravel(), ys.ravel()])
zs = score0_lof.reshape(xs.shape)
# Plot the anomaly score as a map
plt.figure(1, figsize=(15, 5))
plt.subplot(121)
plt.pcolormesh(xs, ys, zs, shading='auto')
plt.scatter(X[:,0], X[:,1], 
           c = np.concatenate((np.full(50, "blue"), np.full(10, "red"))))
plt.xlabel('Speed')
plt.ylabel('Dist')
# Plot the anomaly score by color
score1_lof = -alg_lof.decision_function(X)
plt.subplot(122)
plt.scatter(range(0, score1_lof.shape[0]), score1_lof, c = score1_lof)
plt.axvline(50)
plt.xlabel('Observation index')
plt.ylabel('LOF score')
# Out:
# [[ 0.          0.75757576  1.51515152 ... 73.48484848 74.24242424
#   75.        ]
#  [ 0.          0.75757576  1.51515152 ... 73.48484848 74.24242424
#   75.        ]
#  [ 0.          0.75757576  1.51515152 ... 73.48484848 74.24242424
#   75.        ]
#  ...
#  [ 0.          0.75757576  1.51515152 ... 73.48484848 74.24242424
#   75.        ]
#  [ 0.          0.75757576  1.51515152 ... 73.48484848 74.24242424
#   75.        ]
#  [ 0.          0.75757576  1.51515152 ... 73.48484848 74.24242424
#   75.        ]] [[-5.00000000e+00 -5.00000000e+00 -5.00000000e+00 ... -5.00000000e+00
#   -5.00000000e+00 -5.00000000e+00]
#  [-2.42424242e+00 -2.42424242e+00 -2.42424242e+00 ... -2.42424242e+00
#   -2.42424242e+00 -2.42424242e+00]
#  [ 1.51515152e-01  1.51515152e-01  1.51515152e-01 ...  1.51515152e-01
#    1.51515152e-01  1.51515152e-01]
#  ...
#  [ 2.44848485e+02  2.44848485e+02  2.44848485e+02 ...  2.44848485e+02
#    2.44848485e+02  2.44848485e+02]
#  [ 2.47424242e+02  2.47424242e+02  2.47424242e+02 ...  2.47424242e+02
#    2.47424242e+02  2.47424242e+02]
#  [ 2.50000000e+02  2.50000000e+02  2.50000000e+02 ...  2.50000000e+02
#    2.50000000e+02  2.50000000e+02]]
# Text(0, 0.5, 'LOF score')

# %% [markdown]
# ## 3) One-class support vector machine

# %%
# Create and fit the instance of the class
alg_ocsvm = svm.OneClassSVM(nu = outliers_fraction, kernel = "rbf", gamma = 0.0075)
alg_ocsvm.fit(X[:50,:])
# Calculate the anomaly scores for a map
score0_ocsvm = -alg_ocsvm.decision_function(np.c_[xs.ravel(), ys.ravel()])
zs = score0_ocsvm.reshape(xs.shape)
# Plot the anomaly score as a map
plt.figure(1, figsize=(15, 5))
plt.subplot(121)
plt.pcolormesh(xs, ys, zs, shading='auto')
plt.scatter(X[:,0], X[:,1], 
           c = np.concatenate((np.full(50, "blue"), np.full(10, "red"))))
plt.xlabel('Speed')
plt.ylabel('Dist')
# Plot the anomaly score by color
score1_ocsvm = -alg_ocsvm.decision_function(X)
plt.subplot(122)
plt.scatter(range(0, score1_ocsvm.shape[0]), score1_ocsvm, c = score1_ocsvm)
plt.axvline(50)
plt.xlabel('Observation index')
plt.ylabel('OC-SVM score')
# Out:
# Text(0, 0.5, 'OC-SVM score')

# %% [markdown]
# ## 4) Isolation forest

# %%
# Create and fit the instance of the class
alg_if =  IsolationForest(contamination = outliers_fraction, random_state = 1)
alg_if.fit(X[:50,:])
# Calculate the anomaly scores for a map
score0_if = -alg_if.decision_function(np.c_[xs.ravel(), ys.ravel()])
zs = score0_if.reshape(xs.shape)
# Plot the anomaly score as a map
plt.figure(1, figsize=(15, 5))
plt.subplot(121)
plt.pcolormesh(xs, ys, zs, shading='auto')
plt.scatter(X[:,0], X[:,1], 
           c = np.concatenate((np.full(50, "blue"), np.full(10, "red"))))
plt.xlabel('Speed')
plt.ylabel('Dist')
# Plot the anomaly score by color
score1_if = -alg_if.decision_function(X)
plt.subplot(122)
plt.scatter(range(0, score1_if.shape[0]), score1_if, c = score1_if)
plt.axvline(50)
plt.xlabel('Observation index')
plt.ylabel('IF score')
# Out:
# Text(0, 0.5, 'IF score')

# %% [markdown]
# ## 6) Data depth

# %%
# Calculate the anomaly scores for a map
score0_depthPr = -depthPrj(np.c_[xs.ravel(), ys.ravel()], X[:50,:])
zs = score0_depthPr.reshape(xs.shape)
# Plot the anomaly score as a map
plt.figure(1, figsize=(15, 5))
plt.subplot(121)
plt.pcolormesh(xs, ys, zs, shading='auto')
plt.scatter(X[:,0], X[:,1], 
           c = np.concatenate((np.full(50, "blue"), np.full(10, "red"))))
plt.xlabel('Speed')
plt.ylabel('Dist')
# Plot the anomaly score by color
score1_depthPr = -depthPrj(X, X[:50,:])
plt.subplot(122)
plt.scatter(range(0, score1_depthPr.shape[0]), score1_depthPr, c = score1_depthPr)
plt.axvline(50)
plt.xlabel('Observation index')
plt.ylabel('Projection depth score')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 2
#       1 # Calculate the anomaly scores for a map
# ----> 2 score0_depthPr = -depthPrj(np.c_[xs.ravel(), ys.ravel()], X[:50,:])
#       3 zs = score0_depthPr.reshape(xs.shape)
#       4 # Plot the anomaly score as a map
#
# File ~/PycharmProjects/rkm/rkm/depth/depth_routines.py:85, in depthPrj(X, data, ndirs)
#      83     for i in range(len(X)):
#      84         prjCurX = X[i] @ dirs[j]
# ---> 85         curDepth = 1 / (1 + np.abs(prjCurX - np.median(prjData)) / prjMAD)
#      86         depths[i] = min([depths[i], curDepth])
#      87 return depths
#
# File <__array_function__ internals>:180, in median(*args, **kwargs)
#
# File ~/opt/miniconda3/envs/rkm/lib/python3.10/site-packages/numpy/lib/function_base.py:3793, in median(a, axis, out, overwrite_input, keepdims)
#    3711 @array_function_dispatch(_median_dispatcher)
#    3712 def median(a, axis=None, out=None, overwrite_input=False, keepdims=False):
#    3713     """
#    3714     Compute the median along the specified axis.
#    3715
#    (...)
#    3791
#    3792     """
# -> 3793     r, k = _ureduce(a, func=_median, axis=axis, out=out,
#    3794                     overwrite_input=overwrite_input)
#    3795     if keepdims:
#    3796         return r.reshape(k)
#
# File ~/opt/miniconda3/envs/rkm/lib/python3.10/site-packages/numpy/lib/function_base.py:3702, in _ureduce(a, func, **kwargs)
#    3699 else:
#    3700     keepdim = (1,) * a.ndim
# -> 3702 r = func(a, **kwargs)
#    3703 return r, keepdim
#
# File ~/opt/miniconda3/envs/rkm/lib/python3.10/site-packages/numpy/lib/function_base.py:3851, in _median(a, axis, out, overwrite_input)
#    3848 # Check if the array contains any nan's
#    3849 if np.issubdtype(a.dtype, np.inexact) and sz > 0:
#    3850     # If nans are possible, warn and replace by nans like mean would.
# -> 3851     rout = np.lib.utils._median_nancheck(part, rout, axis)
#    3853 return rout
#
# File ~/opt/miniconda3/envs/rkm/lib/python3.10/site-packages/numpy/lib/utils.py:1028, in _median_nancheck(data, result, axis)
#    1026 if data.size == 0:
#    1027     return result
# -> 1028 n = np.isnan(data.take(-1, axis=axis))
#    1029 # masked NaN values are ok
#    1030 if np.ma.isMaskedArray(n):
#
# KeyboardInterrupt:

# %%
# Calculate the anomaly scores for a map
# score0_depthPr = - depthTuk(np.c_[xs.ravel(), ys.ravel()], X[:50,:])
score0_depthPr = - depth_tukey(np.c_[xs.ravel(), ys.ravel()], X[:50,:])
zs = score0_depthPr.reshape(xs.shape)
# Plot the anomaly score as a map
plt.figure(1, figsize=(15, 5))
plt.subplot(121)
plt.pcolormesh(xs, ys, zs, shading='auto')
plt.scatter(X[:,0], X[:,1],
           c = np.concatenate((np.full(50, "blue"), np.full(10, "red"))))
plt.xlabel('Speed')
plt.ylabel('Dist')
# Plot the anomaly score by color
score1_depthPr = -depthPrj(X, X[:50,:])
plt.subplot(122)
plt.scatter(range(0, score1_depthPr.shape[0]), score1_depthPr, c = score1_depthPr)
plt.axvline(50)
plt.xlabel('Observation index')
plt.ylabel('Projection depth score')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 3
#       1 # Calculate the anomaly scores for a map
#       2 # score0_depthPr = - depthTuk(np.c_[xs.ravel(), ys.ravel()], X[:50,:])
# ----> 3 score0_depthPr = - depth_tukey(np.c_[xs.ravel(), ys.ravel()], X[:50,:])
#       4 zs = score0_depthPr.reshape(xs.shape)
#       5 # Plot the anomaly score as a map
#
# NameError: name 'depth_tukey' is not defined
